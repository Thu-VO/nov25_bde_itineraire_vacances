# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\DELL\\Downloads\\ItineraireVacances\\.venv\\Scripts\\python.exe'

# %% [markdown]
# # Dataset — datatourisme-reg-idf
# (17.6 MB, 1 file, 42 columns, 3k downloads, Mise à jour joualière)
#
#
# https://www.data.gouv.fr/datasets/datatourisme-la-base-nationale-des-donnees-publiques-dinformation-touristique-en-open-data

# %% [markdown]
# # 1. Charger les données

# %%
import pandas as pd
import numpy as np
import re
import pyarrow
import folium
from folium.plugins import MarkerCluster

# %%
#lire CSV_PATH
CSV_PATH = "datatourisme-reg-idf.csv"
df_gov = pd.read_csv(CSV_PATH, sep = ",", encoding = "utf-8", encoding_errors="replace", low_memory = False)

#Convertir en Parquet --> Fichier beaucoup plus léger --> Lecture rapide
PARQUET_PATH = "datatourisme-reg-idf.parquet"
df_gov.to_parquet(PARQUET_PATH, compression = "snappy")

#Libère la mémoire et recharger le parquet
del df_gov
df_gov = pd.read_parquet("datatourisme-reg-idf.parquet")

#Afficher 2 lignes et TOUTES les colonnes
pd.set_option("display.max_columns", None)
display(df_gov.head(3))

print("\n-------------------------------------")
print("Nombre de lignes et de colones")
print(df_gov.shape)

print("\n-------------------------------------")
print("Display info sur les colonnes et datatype")
pd.set_option("display.max_colwidth", 40)
display(df_gov.info())
# Out:
#                             Nom_du_POI  \
# 0                         Hôtel Andréa
# 1  Novotel Saint-Quentin Golf National
# 2         Adagio Paris Buttes-Chaumont
#
#                          Categories_de_POI   Latitude  Longitude  \
# 0  https://www.datatourisme.fr/ontology...  48.858204   2.350293
# 1  https://www.datatourisme.fr/ontology...  48.754290   2.074922
# 2  https://www.datatourisme.fr/ontology...  48.877940   2.387374
#
#        Adresse_postale   Code_postal_et_commune Periodes_regroupees  \
# 0      3 rue Saint-Bon              75004#Paris                None
# 1     1 avenue du Golf  78114#Magny-les-Hameaux                None
# 2  3-5 cours du 7e Art              75019#Paris                None
#
#    Covid19_mesures_specifiques        Createur_de_la_donnee  \
# 0                          NaN  Office de Tourisme de Paris
# 1                          NaN  Office de Tourisme de Paris
# 2                          NaN  Office de Tourisme de Paris
#
#                  SIT_diffuseur Date_de_mise_a_jour  \
# 0  Office de Tourisme de Paris          2025-12-04
# 1  Office de Tourisme de Paris          2025-12-04
# 2  Office de Tourisme de Paris          2025-12-04
#
#                  Contacts_du_POI                       Classements_du_POI  \
# 0  #http://hotelandrea.paris/fr/  3 étoiles#Classement officiel des hé...
# 1       #http://www.novotel.com/  4 étoiles#Classement officiel des hé...
# 2   #http://www.adagio-city.com/  3 étoiles#Classement officiel des hé...
#
#                                Description  \
# 0  Découvrez l'Hôtel Andrea, idéalement...
# 1  Le Novotel Saint-Quentin Golf Nation...
# 2  Situé près du Parc des Buttes Chaumo...
#
#                              URI_ID_du_POI
# 0  https://data.datatourisme.fr/19/05d6...
# 1  https://data.datatourisme.fr/19/25c4...
# 2  https://data.datatourisme.fr/19/25e0...
# -------------------------------------
# Nombre de lignes et de colones
# (10434, 15)
#
# -------------------------------------
# Display info sur les colonnes et datatype
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10434 entries, 0 to 10433
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nom_du_POI                   10434 non-null  object
#  1   Categories_de_POI            10434 non-null  object
#  2   Latitude                     10434 non-null  float64
#  3   Longitude                    10434 non-null  float64
#  4   Adresse_postale              10230 non-null  object
#  5   Code_postal_et_commune       10434 non-null  object
#  6   Periodes_regroupees          449 non-null    object
#  7   Covid19_mesures_specifiques  0 non-null      float64
#  8   Createur_de_la_donnee        10434 non-null  object
#  9   SIT_diffuseur                10434 non-null  object
#  10  Date_de_mise_a_jour          10434 non-null  object
#  11  Contacts_du_POI              10289 non-null  object
#  12  Classements_du_POI           1252 non-null   object
#  13  Description                  9992 non-null   object
#  14  URI_ID_du_POI                10434 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# # 2. Décrire les données

# %%
print("---------------------------------------")
print("Les valeurs uniques de la colonne Nom_du_POI :")
print("---------------------------------------")
display(df_gov["Nom_du_POI"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Categories_de_POI :")
print("---------------------------------------")
display(df_gov["Categories_de_POI"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Adresse_postale :")
print("---------------------------------------")
display(df_gov["Adresse_postale"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Code_postal_et_commune :")
print("---------------------------------------")
display(df_gov["Code_postal_et_commune"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Periodes_regroupees :")
print("---------------------------------------")
display(df_gov["Periodes_regroupees"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Createur_de_la_donnee :")
print("---------------------------------------")
display(df_gov["Createur_de_la_donnee"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne SIT_diffuseur :")
print("---------------------------------------")
display(df_gov["SIT_diffuseur"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Date_de_mise_a_jour :")
print("---------------------------------------")
display(df_gov["Date_de_mise_a_jour"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Contacts_du_POI :")
print("---------------------------------------")
display(df_gov["Contacts_du_POI"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Classements_du_POI :")
print("---------------------------------------")
display(df_gov["Classements_du_POI"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne URI_ID_du_POI :")
print("---------------------------------------")
display(df_gov["URI_ID_du_POI"].unique()[:10])

print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Description :")
print("---------------------------------------")
display(df_gov["Description"].unique()[:10])
# Out:
# ---------------------------------------
# Les valeurs uniques de la colonne Nom_du_POI :
# ---------------------------------------
# array(['Hôtel Andréa', 'Novotel Saint-Quentin Golf National',
#        'Adagio Paris Buttes-Chaumont', 'Maison Souquet',
#        'Le Bar de la Maison Souquet', "Disney's Hotel Cheyenne®",
#        'Nest Paris La Défense By MGallery', 'Timhotel Paris Gare de Lyon',
#        'Le Louis Versailles Château - MGallery Hotel Collection',
#        "L'Alcôve"], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Categories_de_POI :
# ---------------------------------------
# array(['https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Accommodation|https://www.datatourisme.fr/ontology/core#Hotel|https://www.datatourisme.fr/ontology/core#HotelTrade|http://schema.org/Accommodation|http://schema.org/LodgingBusiness|http://schema.org/Hotel',
#        'https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Accommodation|https://www.datatourisme.fr/ontology/core#CollectiveAccommodation|https://www.datatourisme.fr/ontology/core#HolidayResort|http://schema.org/Accommodation|http://schema.org/LodgingBusiness',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#SportsAndLeisurePlace|https://www.datatourisme.fr/ontology/core#BistroOrWineBar|http://schema.org/FoodEstablishment|http://schema.org/Winery',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#BarOrPub|http://schema.org/FoodEstablishment',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|http://schema.org/FoodEstablishment',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#BistroOrWineBar|http://schema.org/FoodEstablishment|http://schema.org/Winery',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Restaurant|https://www.datatourisme.fr/ontology/core#BrasserieOrTavern|http://schema.org/FoodEstablishment|http://schema.org/Restaurant',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Restaurant|https://www.datatourisme.fr/ontology/core#Accommodation|https://www.datatourisme.fr/ontology/core#Hotel|https://www.datatourisme.fr/ontology/core#HotelRestaurant|https://www.datatourisme.fr/ontology/core#HotelTrade|http://schema.org/Accommodation|http://schema.org/FoodEstablishment|http://schema.org/LodgingBusiness|http://schema.org/Restaurant|http://schema.org/Hotel',
#        'https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#SportsAndLeisurePlace',
#        'https://www.datatourisme.fr/ontology/core#Hotel|https://www.datatourisme.fr/ontology/core#HotelRestaurant|https://www.datatourisme.fr/ontology/core#HotelTrade|http://schema.org/Accommodation|http://schema.org/FoodEstablishment|http://schema.org/LodgingBusiness|http://schema.org/Restaurant|http://schema.org/Hotel|https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Restaurant|https://www.datatourisme.fr/ontology/core#Accommodation'],
#       dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Adresse_postale :
# ---------------------------------------
# array(['3 rue Saint-Bon', '1 avenue du Golf', '3-5 cours du 7e Art',
#        '10 rue de Bruxelles', 'Rue du Bœuf Agile',
#        '34 cours Michelet (accès piéton) - 33 voie des sculpteurs (accès routier)',
#        "1 bis-3 rue d'Austerlitz", '2 bis avenue de Paris',
#        '79 rue Lauriston', '426 avenue du Général de Gaulle'],
#       dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Code_postal_et_commune :
# ---------------------------------------
# array(['75004#Paris', '78114#Magny-les-Hameaux', '75019#Paris',
#        '75009#Paris', '77700#Coupvray', '92060#Puteaux', '75012#Paris',
#        '78000#Versailles', '75116#Paris', '92140#Clamart'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Periodes_regroupees :
# ---------------------------------------
# array([None,
#        '2025-10-01<->2025-03-31|2025-04-01<->2025-09-30|2025-12-01<->2025-03-30',
#        '2025-01-01<->2025-12-31',
#        '2025-03-13<->2025-03-13|2025-03-14<->2025-03-15|2025-03-11<->2025-03-12',
#        '2025-04-16<->2025-04-19', '2025-05-30<->2025-05-31',
#        '2025-04-22<->2025-04-26', '2025-05-07<->2025-05-10',
#        '2025-02-14<->2025-02-14', '2025-10-31<->2025-03-08'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Createur_de_la_donnee :
# ---------------------------------------
# array(['Office de Tourisme de Paris', 'Choose Paris Region',
#        'Office de Tourisme et des Congrès de Versailles Grand Parc',
#        'Conseil Départemental des Yvelines',
#        'Office de Tourisme Intercommunal de Saint Germain Boucles de Seine',
#        'Agence POP – Plaine commune vous Ouvre ses Portes',
#        'Office de Tourisme Grand Roissy',
#        "Communauté d'Agglomération de l'Etampois Sud-Essonne",
#        'Dourdan Tourisme', 'Communauté Urbaine Grand Paris Seine & Oise'],
#       dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne SIT_diffuseur :
# ---------------------------------------
# array(['Office de Tourisme de Paris',
#        'Apidae Tourisme Scic SA - source : Apidae Tourisme',
#        'Seine et Marne Attractivité - source : Apidae Tourisme',
#        'Administrateur ADRT62'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Date_de_mise_a_jour :
# ---------------------------------------
# array(['2025-12-04', '2024-02-13', '2023-08-24', '2025-04-02',
#        '2025-02-18', '2024-10-11', '2024-08-16', '2024-01-15',
#        '2024-02-23', '2024-02-04'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Contacts_du_POI :
# ---------------------------------------
# array(['#http://hotelandrea.paris/fr/', '#http://www.novotel.com/',
#        '#http://www.adagio-city.com/', '#https://www.maisonsouquet.com/',
#        '#https://www.maisonsouquet.com/fr/',
#        '#http://www.disneylandparis.fr/hotels/disneys-hotel-cheyenne/',
#        '#https://all.accor.com/hotel/0912/index.fr.shtml',
#        '#http://www.timhotel.com/fr/nos-hotels-details/29-timhotel-paris-gare-de-lyon.htm',
#        '#https://all.accor.com/hotel/1300/index.fr.shtml',
#        '#https://restaurant-lalcove.com/'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Classements_du_POI :
# ---------------------------------------
# array(['3 étoiles#Classement officiel des hébergements touristiques',
#        '4 étoiles#Classement officiel des hébergements touristiques',
#        '5 étoiles#Classement officiel des hébergements touristiques',
#        None,
#        '2 étoiles#Classement officiel des hébergements touristiques',
#        'Accueil Vélo#France Vélo Tourisme|3 étoiles#Classement officiel des hébergements touristiques',
#        'Clef Verte#Clef verte|5 étoiles#Classement officiel des hébergements touristiques',
#        'Tourisme & Handicap mental#Marque Tourisme et Handicap|Tourisme & Handicap moteur#Marque Tourisme et Handicap|5 étoiles#Classement officiel des hébergements touristiques|Tourisme & Handicap auditif#Marque Tourisme et Handicap|Tourisme & Handicap visuel#Marque Tourisme et Handicap',
#        'Clef Verte#Clef verte|4 étoiles#Classement officiel des hébergements touristiques',
#        'Accueil Vélo#France Vélo Tourisme'], dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne URI_ID_du_POI :
# ---------------------------------------
# array(['https://data.datatourisme.fr/19/05d67a14-c1aa-34ea-989d-72445d729f6c',
#        'https://data.datatourisme.fr/19/25c4307e-ebfe-3522-9bd6-467e0a9b1e5f',
#        'https://data.datatourisme.fr/19/25e0ad9a-0fce-3707-9b81-30c5bfbfea42',
#        'https://data.datatourisme.fr/19/25e6474a-6143-3771-b3a5-7308fd651728',
#        'https://data.datatourisme.fr/13/4d200ad2-d4b2-332f-929c-e126d2601f64',
#        'https://data.datatourisme.fr/19/822bd6de-7ce6-392a-96a1-4bee1ee59ee1',
#        'https://data.datatourisme.fr/19/266589e4-d7e0-30b9-a919-480e2c02f9ab',
#        'https://data.datatourisme.fr/19/270bdd3d-c7be-32e8-9772-e44cd4bc30e7',
#        'https://data.datatourisme.fr/19/27676e2d-e22a-3313-a4c2-9a5c0f75baaa',
#        'https://data.datatourisme.fr/19/27796e11-c00b-3d65-9589-99a00e46c0b3'],
#       dtype=object)
# -------------------------------------
# Les valeurs uniques de la colonne Description :
# ---------------------------------------
# array(["Découvrez l'Hôtel Andrea, idéalement situé près de l'Hôtel de Ville de Paris et du quartier du Marais. Dans un bel immeuble du XXe siècle, l'établissement vous offre un cadre élégant pour votre séjour. Chaque chambre allie modernité et charme ancien. Profitez du confort et des services haut de gamme, tout en explorant les trésors de la ville lumière. Réservez maintenant pour une expérience inoubliable à l'Hôtel Andrea.",
#        "Le Novotel Saint-Quentin Golf National, au cœur du Golf National, accueillera la Ryder Cup 2018 et l'Open de France. Avec ses 131 chambres, 11 salles de réunion et un amphithéâtre, c'est l'endroit parfait pour vos événements. Niché dans un cadre exceptionnel entouré de parcours de golf renommés, l'hôtel propose également un restaurant, un club house, une piscine et 2 courts de tennis. Une expérience complète de Resort aux portes de Paris.",
#        "Situé près du Parc des Buttes Chaumont et du Canal de l'Ourcq, l'Adagio Paris Buttes Chaumont vous propose un environnement calme. Dans un bâtiment moderne avec cour intérieure, il offre 97 appartements, du studio au 3 pièces. Ce quartier parisien typique regorge de commerces et services, et le centre de Paris est facilement accessible en métro. Un parking couvert privé est également disponible pour votre confort.",
#        'Située entre Montmartre et SoPi, la Maison Souquet est un hôtel 5 étoiles au décor somptueux de Jacques Garcia. Avec ses 14 chambres et 6 suites uniques, cet ancien hôtel particulier séduit par son charme. Le salon des Mille et une Nuits, le bar à cocktails, le spa, le hammam et le bassin de 10 mètres ajoutent une touche de luxe. Une adresse incontournable pour vivre une expérience unique à Paris.',
#        'Maison Souquet, nouvel écrin coquin à Pigalle', None,
#        "Optez pour un séjour dépaysant et convivial au Disney's Hotel Cheyenne® ! Plongez dans l'ambiance western du Grand Ouest à seulement 20 minutes de marche des Parcs Disneyland® Paris. Vous serez charmés par les décors typiques des cow-boys, saloons et restaurants du Far West. Avec un excellent rapport qualité-prix pour les familles et les groupes d'amis, cet établissement promet une expérience mémorable.",
#        "Découvrez le Nest Hotel Paris La Défense by MGallery Collection, un havre de paix au cœur du quartier d'affaires. Réinventé par Oscar Lucien Ono, cet établissement 5 étoiles mêle modernité et convivialité. Profitez de l'ambiance chaleureuse et reposante de cet hôtel au design raffiné. Dégustez une cuisine délicieuse et de saison au restaurant Ô Mazette, illuminé par la lumière naturelle de sa verrière. Une expérience unique vous attend au Nest Hotel Paris La Défense.",
#        'Au cœur de Paris, la Gare de Lyon relie de nombreuses métropoles françaises à la capitale et permet de rejoindre des sites emblématiques comme l’Étoile, Auber, Disneyland Paris ou la Défense. Le Timhotel Paris Gare de Lyon, situé dans ce quartier animé, est un pied-à-terre idéal pour explorer la ville. Installé dans un bel immeuble parisien, le personnel polyglotte est disponible 24h/24 pour garantir un séjour agréable dans un cadre chaleureux et authentique.',
#        "Situé près du Château de Versailles, l'hôtel 4 étoiles Le Louis mêle histoire et luxe. Restaurant, bar, fitness, sauna, salles de réunion et Wi-Fi gratuit sont à disposition. À 2 minutes de la gare Versailles-Château-Rive-Gauche, l'hôtel Pullman permet de rejoindre Paris en 20 minutes. Versailles offre un accès direct à Paris et ses attractions majeures."],
#       dtype=object)

# %% [markdown]
# # 3. Les colonnes à prendre ou à laisser

# %% [markdown]
# ### Les colonnes à garder absolument et à transformer en cas de besoin :
#
# Nom_du_POI, Categories_de_POI, Latitude, Longitude,	Adresse_postale, Code_postal_et_commune, Contacts_du_POI, Classements_du_POI, Description, URI_ID_du_POI
#
# ### Les colonnes à ignorer :
# Periodes_regroupees, Covid19_mesures_specifiques, Createur_de_la_donnee, SIT_diffuseur, Date_de_mise_a_jour

# %% [markdown]
# # 4. Nettoyer + compléter + transformer les données

# %% [markdown]
# #### 4.1. Nettoyer la colonne Categories_de_POI → passer d’URI à labels lisibles + liste de catégories

# %%
#décrire la colonnne Categories_de_POI
print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Categories_de_POI :")
print("---------------------------------------")
display(df_gov["Categories_de_POI"].unique()[:5])
# Out:
# -------------------------------------
# Les valeurs uniques de la colonne Categories_de_POI :
# ---------------------------------------
# array(['https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Accommodation|https://www.datatourisme.fr/ontology/core#Hotel|https://www.datatourisme.fr/ontology/core#HotelTrade|http://schema.org/Accommodation|http://schema.org/LodgingBusiness|http://schema.org/Hotel',
#        'https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#Accommodation|https://www.datatourisme.fr/ontology/core#CollectiveAccommodation|https://www.datatourisme.fr/ontology/core#HolidayResort|http://schema.org/Accommodation|http://schema.org/LodgingBusiness',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#SportsAndLeisurePlace|https://www.datatourisme.fr/ontology/core#BistroOrWineBar|http://schema.org/FoodEstablishment|http://schema.org/Winery',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|https://www.datatourisme.fr/ontology/core#BarOrPub|http://schema.org/FoodEstablishment',
#        'https://www.datatourisme.fr/ontology/core#FoodEstablishment|https://www.datatourisme.fr/ontology/core#PlaceOfInterest|https://www.datatourisme.fr/ontology/core#PointOfInterest|http://schema.org/FoodEstablishment'],
#       dtype=object)

# %%
#créer la colonne Categories_de_POI
#fonction : nettoyer → passer d’URI à labels lisibles + liste de catégories
def uri_to_label(uri: str) -> str:
    """Extrait le label final d'une URI (après # ou /)."""
    if pd.isna(uri) or uri is None:
        return np.nan
    uri = str(uri).strip()
    # coupe sur # sinon sur /
    if "#" in uri:
        return uri.split("#")[-1]
    return uri.rstrip("/").split("/")[-1]

def split_categories(cell: str):
    """Split sur | puis transforme chaque URI en label."""
    if pd.isna(cell) or cell is None:
        return []
    parts = [p.strip() for p in str(cell).split("|") if p.strip()]
    labels = [uri_to_label(p) for p in parts]
    # dédoublonnage en gardant l'ordre
    seen = set()
    out = []
    for x in labels:
        if x not in seen and x is not np.nan:
            seen.add(x)
            out.append(x)
    return out

df_gov["categories_list"] = df_gov["Categories_de_POI"].apply(split_categories)

#vérifier
df_gov[["Categories_de_POI", "categories_list"]].head()
# Out:
#                          Categories_de_POI  \
# 0  https://www.datatourisme.fr/ontology...
# 1  https://www.datatourisme.fr/ontology...
# 2  https://www.datatourisme.fr/ontology...
# 3  https://www.datatourisme.fr/ontology...
# 4  https://www.datatourisme.fr/ontology...
#
#                            categories_list
# 0  [PlaceOfInterest, PointOfInterest, A...
# 1  [PlaceOfInterest, PointOfInterest, A...
# 2  [PlaceOfInterest, PointOfInterest, A...
# 3  [PlaceOfInterest, PointOfInterest, A...
# 4  [FoodEstablishment, PlaceOfInterest,...

# %%
#décrire la colonne "categories_list"
unique_combos = df_gov["categories_list"].apply(tuple).unique()
display(df_gov["categories_list"].apply(tuple).value_counts().head())

#décrire les catégories individuelles de la colonne "categories_list"
all_categories = (df_gov["categories_list"].explode().value_counts())
pd.set_option("display.max_rows", None)
all_categories
# Out:
# categories_list
# (FoodEstablishment, PlaceOfInterest, PointOfInterest)                                    1960
# (PlaceOfInterest, PointOfInterest, Accommodation, Hotel, HotelTrade, LodgingBusiness)     871
# (PlaceOfInterest, PointOfInterest, SportsAndLeisurePlace)                                 741
# (PlaceOfInterest, PointOfInterest, Store, BoutiqueOrLocalShop, LocalBusiness)             522
# (FoodEstablishment, PlaceOfInterest, PointOfInterest, Restaurant)                         411
# Name: count, dtype: int64
# categories_list
# PointOfInterest                      10434
# PlaceOfInterest                       9798
# FoodEstablishment                     3150
# SportsAndLeisurePlace                 2466
# LocalBusiness                         2427
# CulturalSite                          2040
# Accommodation                         1279
# LodgingBusiness                       1279
# Store                                 1226
# Hotel                                 1026
# HotelTrade                            1026
# Restaurant                             723
# BoutiqueOrLocalShop                    524
# Event                                  449
# EntertainmentAndEvent                  449
# Museum                                 423
# Park                                   386
# ParkAndGarden                          386
# Product                                320
# CraftsmanShop                          295
# ReligiousSite                          290
# Winery                                 251
# BistroOrWineBar                        251
# SaleEvent                              225
# Market                                 216
# Visit                                  197
# EquestrianCenter                       188
# CulturalEvent                          187
# RemarkableBuilding                     186
# Church                                 160
# Library                                157
# CollectiveAccommodation                148
# HotelRestaurant                        148
# BarOrPub                               141
# TechnicalHeritage                      133
# StadiumOrArena                         128
# Stadium                                128
# TastingProvider                        122
# Rental                                 118
# HolidayResort                          114
# ArtGalleryOrExhibitionGallery          111
# SwimmingPool                           111
# Cinema                                 104
# MovieTheater                           104
# AmusementPark                           98
# ThemePark                               98
# NightClub                               94
# NonHousingRealEstateRental              93
# FitnessCenter                           90
# ServiceProvider                         88
# GourmetRestaurant                       78
# Theater                                 77
# OrderedList                             74
# ExhibitionEvent                         74
# Tour                                    74
# Exhibition                              74
# RentalAccommodation                     67
# BrasserieOrTavern                       66
# Castle                                  66
# EducationalTrail                        65
# WalkingTour                             65
# CoveredMarket                           63
# GolfCourse                              63
# TouristInformationCenter                63
# Transporter                             59
# LocalTouristOffice                      59
# Transport                               58
# RemembranceSite                         52
# ActivityProvider                        51
# DefenceSite                             51
# SportsEvent                             46
# ShoppingCentreAndGallery                45
# CityHeritage                            41
# CampingAndCaravanning                   38
# TheaterEvent                            38
# ShowEvent                               38
# Camping                                 37
# MilitaryCemetery                        35
# CafeOrCoffeeShop                        35
# CafeOrTeahouse                          35
# Guesthouse                              32
# TrackRollerOrSkateBoard                 32
# BedAndBreakfast                         32
# FastFoodRestaurant                      30
# Farm                                    30
# SelfCateringAccommodation               30
# Hostel                                  28
# Bridge                                  28
# YouthHostelAndInternationalCenter       28
# MedicalPlace                            27
# EquipmentRentalShop                     25
# Zoo                                     25
# ZooAnimalPark                           25
# ConventionCentre                        25
# BusinessPlace                           25
# EquipmentRental                         25
# Mill                                    24
# TeachingFarm                            21
# TrainStation                            20
# SightseeingBoat                         19
# TableHoteGuesthouse                     19
# MusicEvent                              18
# Concert                                 17
# InterpretationCentre                    17
# Cabaret                                 17
# ClimbingWall                            16
# RiverPort                               16
# SportsCompetition                       16
# Pharmacy                                15
# CivicStructure                          14
# Airfield                                13
# TennisComplex                           13
# IceCreamShop                            11
# HealthcarePlace                         11
# NaturalHeritage                         10
# Hammam                                  10
# Festival                                10
# Landform                                10
# ArcheologicalSite                       10
# FitnessPath                             10
# Gymnasium                               10
# AdventurePark                            9
# Cellar                                   9
# Ruins                                    9
# IndustrialSite                           9
# Conference                               8
# Marina                                   8
# CivilCemetery                            8
# FairOrShow                               7
# District                                 7
# RacingCircuit                            7
# DepartmentStore                          7
# Beach                                    6
# TouristTrain                             6
# BowlingAlley                             6
# Cathedral                                6
# LeisureComplex                           5
# GroupLodging                             5
# Palace                                   5
# CircusPlace                              5
# BalneotherapyCentre                      5
# Racetrack                                5
# IceSkatingRink                           5
# Practice                                 5
# LocalProductsShop                        5
# MiniGolf                                 5
# Casino                                   5
# StopOverOrGroupLodge                     5
# AntiqueAndSecondhandGoodDealer           5
# Abbey                                    5
# NauticalCentre                           4
# Temple                                   4
# TaxiCompany                              4
# SocialEvent                              4
# BuddhistTemple                           4
# HorseTour                                4
# Collegiate                               4
# Synagogue                                4
# SquashCourt                              4
# PlayArea                                 4
# Bakery                                   4
# Mosque                                   3
# Lock                                     3
# IncomingTravelAgency                     3
# VivariumAquarium                         3
# LocalAnimation                           3
# Basilica                                 3
# Aquarium                                 3
# FluvialTour                              2
# Monastery                                2
# LevyOrDike                               2
# TourOperatorOrTravelAgency               2
# CyclingTour                              2
# ScreeningEvent                           2
# Airport                                  2
# Canal                                    2
# Cloister                                 2
# TraditionalCelebration                   1
# ResidentialLeisurePark                   1
# FortifiedCastle                          1
# Opera                                    1
# Commanderie                              1
# MultiPurposeRoomOrCommunityRoom          1
# Game                                     1
# Spa                                      1
# Aqueduct                                 1
# Fort                                     1
# Convent                                  1
# Tower                                    1
# Velodrome                                1
# Bastide                                  1
# RoadTour                                 1
# Name: count, dtype: int64

# %%
#créer une colonne main_category où mapper les catégories
#"Accommodation" : {"Accommodation", "CollectiveAccommodation", "RentalAccommodation", "CampingAndCaravanning", "Camping", "Hostel", "Guesthouse", "GroupLodging", 
#"TableHoteGuesthouse", "MultiPurposeRoomOrCommunityRoom", "SelfCateringAccommodation", "YouthHostelAndInternationalCenter", "StopOverOrGroupLodge"},
TYPE = {"Food": {"FoodEstablishment", "Restaurant", "GourmetRestaurant", "FastFoodRestaurant", "BarOrPub", "IceCreamShop", "CafeOrTeahouse", "TastingProvider",
                 "BistroOrWineBar", "Winery", "Brewery", "TastingProvider", "BrasserieOrTavern", "Bakery", "CafeOrCoffeeShop", "BedAndBreakfast", "Cellar"},
        "Hotel": {"Palace", "Hotel", "HotelTrade", "HotelRestaurant", "HolidayResort", "LodgingBusiness"},
        "Religion" : {"ReligiousSite", "Church", "Cathedral", "Synagogue", "Temple", "BuddhistTemple", "Mosque", "Basilica", "Monastery", "Abbey", "Convent"},
        "Library" : {"Library"},
        "Museum": {"Museum"},
        "Monument" : {"CulturalSite", "ArcheologicalSite", "ArtGalleryOrExhibitionGallery", "MilitaryCemetery", "RemarkableBuilding", "TechnicalHeritage",
                      "CityHeritage", "DefenceSite", "RemembranceSite", "CivilCemetery", "CivicStructure", "IndustrialSite", "Ruins", "District", "Mill",
                      "Collegiate", "Cloister", "Commanderie", "Aqueduct", "Fort", "Bastide", "Castle", "Tour", "Tower", "FortifiedCastle", "Visit", "InterpretationCentre"},                
        "Nature": {"Park", "ParkAndGarden", "Farm", "ThemePark", "Zoo", "ZooAnimalPark", "Canal", "ResidentialLeisurePark", "Aquarium", "AdventurePark",
                   "RiverPort", "Bridge", "TeachingFarm", "PlayArea", "AmusementPark", "Beach", "Landform", "NaturalHeritage", "Lock", "LevyOrDike"},
        "Sport": {"SportsAndLeisurePlace", "StadiumOrArena", "EquestrianCenter", "FitnessCenter", "SwimmingPool", "ShoppingCentreAndGallery",
                  "MiniGolf", "Gymnasium", "FitnessPath", "TennisComplex", "SportsCompetition", "GolfCourse", "HorseTour", "EquestrianCenter", "ClimbingWall",
                  "BowlingAlley", "IceSkatingRink", "SquashCourt", "Velodrome", "RacingCircuit", "Racetrack", "TrackRollerOrSkateBoard", "Practice", "NauticalCentre"},
        "Shopping": {"BoutiqueOrLocalShop", "CraftsmanShop", "LocalBusiness", "Store", "BoutiqueOrLocalShop", "Market", "CoveredMarket", "EquipmentRentalShop"},
        "Evenement": {"Event", "EntertainmentAndEvent", "SaleEvent", "CulturalEvent", "ExhibitionEvent", "Exhibition", "ShowEvent", "LocalAnimation", "FairOrShow",
                      "SportsEvent", "TheaterEvent", "SocialEvent", "ScreeningEvent", "Conference", "Festival", "MusicEvent", "NightClub", "Casino", "ConventionCentre",
                      "CircusPlace", "TraditionalCelebration", "FairOrShow"},
        "Cinema": {"Cinema", "MovieTheater", "Theater", "Cabaret", "Concert", "Opera"},
        "Transport" : {"Airport", "TrainStation", "Transporter", "Transport", "TouristTrain", "TaxiCompany", "Airfield", "Marina", "SightseeingBoat", "FluvialTour",
                       "SightseeingBoat", "IncomingTravelAgency", "TourOperatorOrTravelAgency", "RoadTour"},
        "Healthcare" : {"HealthcarePlace", "Spa", "Hammam", "Pharmacy", "MedicalPlace", "BalneotherapyCentre"},
        "Stade" : {"Stadium", "StadiumOrArena"},
        "Service" : {"TouristInformationCenter", "LocalTouristOffice", "ServiceProvider", "ActivityProvider", "BusinessPlace", "IncomingTravelAgency",
                             "TourOperatorOrTravelAgency", "WalkingTour", "CyclingTour", "RoadTour", "EducationalTrail", "InterpretationCentre"},
        "Location" : {"Rental", "NonHousingRealEstateRental", "EquipmentRental"}}

def extract_main_category(cat_list):
    if not isinstance(cat_list, list) or not cat_list:
        return None

    s = set(cat_list)
    for bc, values in TYPE.items():
        if s.intersection(values):
            return bc
    return "other"

df_gov["type"] = df_gov["categories_list"].apply(extract_main_category)
df_gov["type"].value_counts()

# vérifier
type = (df_gov["type"].value_counts())
type
# Out:
# type
# Food         3301
# Sport        1870
# Monument     1560
# Shopping     1289
# Hotel        1104
# Museum        423
# Religion      290
# Evenement     202
# Library       157
# Nature        153
# Transport      84
# Service         1
# Name: count, dtype: int64

# %% [markdown]
# #### 4.2. Nettoyer la colonne Classements_du_POI → Extraire le nombre d’étoiles

# %%
print("\n-------------------------------------")
print("Les valeurs uniques de la colonne Classements_du_POI :")
print("---------------------------------------")
display(df_gov["Classements_du_POI"].unique()[:10])
# Out:
# -------------------------------------
# Les valeurs uniques de la colonne Classements_du_POI :
# ---------------------------------------
# array(['3 étoiles#Classement officiel des hébergements touristiques',
#        '4 étoiles#Classement officiel des hébergements touristiques',
#        '5 étoiles#Classement officiel des hébergements touristiques',
#        None,
#        '2 étoiles#Classement officiel des hébergements touristiques',
#        'Accueil Vélo#France Vélo Tourisme|3 étoiles#Classement officiel des hébergements touristiques',
#        'Clef Verte#Clef verte|5 étoiles#Classement officiel des hébergements touristiques',
#        'Tourisme & Handicap mental#Marque Tourisme et Handicap|Tourisme & Handicap moteur#Marque Tourisme et Handicap|5 étoiles#Classement officiel des hébergements touristiques|Tourisme & Handicap auditif#Marque Tourisme et Handicap|Tourisme & Handicap visuel#Marque Tourisme et Handicap',
#        'Clef Verte#Clef verte|4 étoiles#Classement officiel des hébergements touristiques',
#        'Accueil Vélo#France Vélo Tourisme'], dtype=object)

# %%
#Extraire le nombre d’étoiles (regex robuste)
def extract_stars(value):
    if pd.isna(value):
        return None

    text = str(value)

    # cherche "X étoile" ou "X étoiles"
    match = re.search(r'([1-5])\s*étoiles?', text)
    if match:
        return int(match.group(1))
    return None

#vérifier la colonne rating_stars
df_gov["rating_stars"] = df_gov["Classements_du_POI"].apply(extract_stars)
rating_stars = df_gov["rating_stars"].value_counts()
display(rating_stars)

rating_stars_isna = df_gov["rating_stars"].isna().value_counts()
rating_stars_isna
# Out:
# rating_stars
# 3.0    409
# 4.0    406
# 2.0    133
# 5.0     85
# 1.0     54
# Name: count, dtype: int64
# rating_stars
# True     9347
# False    1087
# Name: count, dtype: int64

# %% [markdown]
# #### 4.3. Séparer la colonne Code_postal_et_commune en 2 colonnes : Code_postal, commune

# %%
# Séparation Code_postal_et_commune
col = "Code_postal_et_commune"
parts = (df_gov[col].astype(str).str.split("#", n=1, expand=True))

df_gov["postal_code"] = parts[0].str.strip()
df_gov["commune"] = parts[1].str.strip()

# Vérification
df_gov[["postal_code", "commune"]].head()
# Out:
#   postal_code            commune
# 0       75004              Paris
# 1       78114  Magny-les-Hameaux
# 2       75019              Paris
# 3       75009              Paris
# 4       75009              Paris

# %% [markdown]
# #### 4.4. Créer la colonne "price_level" en basant sur "rating_stars" : 1=petit=hotel 1&2⭐ ; 2=moyen=hotel 3&4⭐ ; 3=confort=hotel 5⭐ ;

# %%
is_hotel = df_gov["type"] == "Hotel"
df_gov.loc[is_hotel & df_gov["rating_stars"].isin([1, 2]), "price_level"] = 1
df_gov.loc[is_hotel & df_gov["rating_stars"].isin([3, 4]), "price_level"] = 2
df_gov.loc[is_hotel & (df_gov["rating_stars"] == 5), "price_level"] = 3

# Vérification
df_gov[["type", "rating_stars", "price_level"]].head(10)
# Out:
#     type  rating_stars  price_level
# 0  Hotel           3.0          2.0
# 1  Hotel           4.0          2.0
# 2  Hotel           3.0          2.0
# 3  Hotel           5.0          3.0
# 4   Food           NaN          NaN
# 5   Food           NaN          NaN
# 6  Hotel           2.0          1.0
# 7  Hotel           5.0          3.0
# 8  Hotel           3.0          2.0
# 9  Hotel           4.0          2.0

# %% [markdown]
# #### 4.5. Extraire url de la colonne "Contacts_du_POI"

# %%
#extraire uniquement les URLs valides (regex) et Gérer les valeurs manquantes
df_gov["url"] = df_gov["Contacts_du_POI"].fillna("").str.extract(r'(https?://[^\s]+)')
df_gov[["Contacts_du_POI", "url"]].head()
# Out:
#                       Contacts_du_POI                                url
# 0       #http://hotelandrea.paris/fr/       http://hotelandrea.paris/fr/
# 1            #http://www.novotel.com/            http://www.novotel.com/
# 2        #http://www.adagio-city.com/        http://www.adagio-city.com/
# 3     #https://www.maisonsouquet.com/     https://www.maisonsouquet.com/
# 4  #https://www.maisonsouquet.com/fr/  https://www.maisonsouquet.com/fr/

# %% [markdown]
# # 5. DataFrame Final (normer les colonnes afin de mapper avec les autres datasets dans streamlit)
#
# 19 colonnes normées UX streamlit : source_id, source, type, raw_type, url, lat, lon, name, address, postal_code, city, region, country, snippet, rating, review_count, price_level, max_people, distance_km

# %%
# Garder uniquement les colonnes utiles
cols_keep = ["URI_ID_du_POI", "Categories_de_POI", "Nom_du_POI", "Latitude", "Longitude", "Adresse_postale", "Description",
             "rating_stars", "postal_code", "commune", "price_level", "url", "type"]
df_gov_clean = df_gov[cols_keep].copy()


# Créer les colonnes standards et les colonnes manquantes pour UX design
df_gov_clean["source"] = "datatourisme-reg-idf"
df_gov_clean["country"] = "France"
df_gov_clean["region"] = "île-de-france"
df_gov_clean["review_count"] = np.nan
df_gov_clean["max_people"] = np.nan
df_gov_clean["distance_km"] = np.nan


#renommer les colonnes
rename_map = {"URI_ID_du_POI": "source_id",
              "Categories_de_POI": "raw_type",
              "Latitude": "lat",
              "Longitude": "lon",
              "Nom_du_POI": "name",
              "Adresse_postale": "address",
              "Commune": "city",
              "rating_stars": "rating",
              "Description": "snippet"}
df_gov_clean_norm = df_gov_clean.rename(columns = rename_map, errors="ignore")


# réordonner les colonnes UX
UX_COLUMNS = ["source_id", "source", "type", "raw_type", "url", "lat", "lon",
              "name", "address", "postal_code", "city", "region", "country",
              "snippet", "rating", "review_count", "price_level", "max_people", "distance_km"]

for col in UX_COLUMNS:
    if col not in df_gov_clean_norm.columns:
        df_gov_clean_norm[col] = None
        
df_gov_clean_normux = df_gov_clean_norm[UX_COLUMNS]

#sauvegarder les changements
df_gov_clean_normux_fast = df_gov_clean_normux.copy()

#aléger le df en mode parquet
df_gov_clean_normux_fast.to_parquet("df_gov_clean_normux_fast.parquet", index=False)

#vérifier
display(df_gov_clean_normux_fast.info())
display(df_gov_clean_normux_fast.head(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10434 entries, 0 to 10433
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source_id     10434 non-null  object
#  1   source        10434 non-null  object
#  2   type          10434 non-null  object
#  3   raw_type      10434 non-null  object
#  4   url           8376 non-null   object
#  5   lat           10434 non-null  float64
#  6   lon           10434 non-null  float64
#  7   name          10434 non-null  object
#  8   address       10230 non-null  object
#  9   postal_code   10434 non-null  object
#  10  city          0 non-null      object
#  11  region        10434 non-null  object
#  12  country       10434 non-null  object
#  13  snippet       9992 non-null   object
#  14  rating        1087 non-null   float64
#  15  review_count  0 non-null      float64
#  16  price_level   941 non-null    float64
#  17  max_people    0 non-null      float64
#  18  distance_km   0 non-null      float64
# dtypes: float64(7), object(12)
# memory usage: 1.5+ MB
# None
#                                  source_id                source   type  \
# 0  https://data.datatourisme.fr/19/05d6...  datatourisme-reg-idf  Hotel
# 1  https://data.datatourisme.fr/19/25c4...  datatourisme-reg-idf  Hotel
# 2  https://data.datatourisme.fr/19/25e0...  datatourisme-reg-idf  Hotel
#
#                                   raw_type                           url  \
# 0  https://www.datatourisme.fr/ontology...  http://hotelandrea.paris/fr/
# 1  https://www.datatourisme.fr/ontology...       http://www.novotel.com/
# 2  https://www.datatourisme.fr/ontology...   http://www.adagio-city.com/
#
#          lat       lon                                 name  \
# 0  48.858204  2.350293                         Hôtel Andréa
# 1  48.754290  2.074922  Novotel Saint-Quentin Golf National
# 2  48.877940  2.387374         Adagio Paris Buttes-Chaumont
#
#                address postal_code  city         region country  \
# 0      3 rue Saint-Bon       75004  None  île-de-france  France
# 1     1 avenue du Golf       78114  None  île-de-france  France
# 2  3-5 cours du 7e Art       75019  None  île-de-france  France
#
#                                    snippet  rating  review_count  price_level  \
# 0  Découvrez l'Hôtel Andrea, idéalement...     3.0           NaN          2.0
# 1  Le Novotel Saint-Quentin Golf Nation...     4.0           NaN          2.0
# 2  Situé près du Parc des Buttes Chaumo...     3.0           NaN          2.0
#
#    max_people  distance_km
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN

# %% [markdown]
# # 6. Carte de points avec clustering

# %%
""""
#Créer la carte
m = folium.Map(location=[48.85, 2.35], zoom_start=9, tiles="OpenStreetMap")

#Ajouter le clustering
marker_cluster = MarkerCluster().add_to(m)

#Ajouter les POI
for _, row in df_gov.iterrows():
    folium.Marker(location=[row["lat"], row["lon"]], popup=f"""<b>{row["main_category"]}</b><br><br></b>{row["name"]}</b><br><br>{row["address"]}<br><br>{row["rating"]}<br><br>""").add_to(marker_cluster)

m.save("map_datatourisme_idf.html")
m
""""
